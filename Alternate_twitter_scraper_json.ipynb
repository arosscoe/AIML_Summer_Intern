# %%
import os
import pandas as pd

# Setting variables to be used in format string command below
tweet_count = 500
text_query = "tame impala"
since_date = "2022-01-01"
until_date = "2022-02-28"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df2 = pd.read_json('text-query-tweets.json', lines=True)

# Displays first 5 entries from dataframe
tweets_df2.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/amorphiliac/status/1498083...
# 1  https://twitter.com/MorningMagic420/status/149...
# 2  https://twitter.com/hutmeow/status/14980818970...
# 3  https://twitter.com/javieraplin/status/1498080...
# 4  https://twitter.com/arrobaepi/status/149807965...
#
#                        date  \
# 0 2022-02-27 23:52:23+00:00
# 1 2022-02-27 23:52:04+00:00
# 2 2022-02-27 23:45:31+00:00
# 3 2022-02-27 23:41:29+00:00
# 4 2022-02-27 23:36:37+00:00
#
#                                              content  \
# 0                                 TAME IMPALA FUCKS.
# 1  i NEED to go to a tame impala concert before I...
# 2      tame impala tem umas musica que doi o coracao
# 3  Tú me puedes decir cómo va mi historia :)\n\nI...
# 4  cara, eu fui ouvir currents do tame impala dep...
#
#                                      renderedContent                   id  \
# 0                                 TAME IMPALA FUCKS.  1498083622271733765
# 1  i NEED to go to a tame impala concert before I...  1498083544345677824
# 2      tame impala tem umas musica que doi o coracao  1498081897070616582
# 3  Tú me puedes decir cómo va mi historia :)\n\nI...  1498080880832700416
# 4  cara, eu fui ouvir currents do tame impala dep...  1498079653730398212
#
#                                                 user  replyCount  \
# 0  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...           2
#
#    retweetCount  likeCount  ...  media  retweetedTweet quotedTweet  \
# 0             0          0  ...   None             NaN        None
# 1             0          0  ...   None             NaN        None
# 2             0          1  ...   None             NaN        None
# 3             0          0  ...   None             NaN        None
# 4             0          1  ...   None             NaN        None
#
#   inReplyToTweetId inReplyToUser  \
# 0              NaN          None
# 1              NaN          None
# 2              NaN          None
# 3              NaN          None
# 4              NaN          None
#
#                                       mentionedUsers coordinates place  \
# 0                                               None        None  None
# 1                                               None        None  None
# 2                                               None        None  None
# 3  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 4                                               None        None  None
#
#   hashtags  cashtags
# 0     None       NaN
# 1     None       NaN
# 2     None       NaN
# 3     None       NaN
# 4     None       NaN
#
# [5 rows x 28 columns]

# %%
# Export dataframe into a CSV
tweets_df2.to_csv('text-query-tweets.csv', sep=',', index=False)
